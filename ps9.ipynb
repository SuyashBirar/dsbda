# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag

# Download required resources (run once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text = """Students are learning data science. 
They are studying machine learning and artificial intelligence."""

# %%
#Tokenization - Splitting text into words
tokens = word_tokenize(text)
print("Tokens:", tokens)
# Out:
# Tokens: ['Students', 'are', 'learning', 'data', 'science', '.', 'They', 'are', 'studying', 'machine', 'learning', 'and', 'artificial', 'intelligence', '.']

# %%
#Stop Words Removal - Remove common words (is, are, the, etc.)
stop_words = set(stopwords.words('english'))

filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
print("After Stopword Removal:", filtered_tokens)
# Out:
# After Stopword Removal: ['Students', 'learning', 'data', 'science', '.', 'studying', 'machine', 'learning', 'artificial', 'intelligence', '.']

# %%
#Stemming - Reduces words to root form
ps = PorterStemmer()
stemmed = [ps.stem(word) for word in filtered_tokens]
print("Stemmed Words:", stemmed)
# Out:
# Stemmed Words: ['student', 'learn', 'data', 'scienc', '.', 'studi', 'machin', 'learn', 'artifici', 'intellig', '.']

# %%
#Lemmatization - Converts words to meaningful base form
lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print("Lemmatized Words:", lemmatized)
# Out:
# Lemmatized Words: ['Students', 'learning', 'data', 'science', '.', 'studying', 'machine', 'learning', 'artificial', 'intelligence', '.']

# %%
#POS Tagging - Identify parts of speech (noun, verb, etc.)
pos_tags = pos_tag(filtered_tokens)
print("POS Tags:", pos_tags)
# Out:
# POS Tags: [('Students', 'NNS'), ('learning', 'VBG'), ('data', 'NNS'), ('science', 'NN'), ('.', '.'), ('studying', 'VBG'), ('machine', 'NN'), ('learning', 'VBG'), ('artificial', 'JJ'), ('intelligence', 'NN'), ('.', '.')]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
docs = [
    "Students are learning data science",
    "Machine learning is a part of artificial intelligence",
    "Data science includes machine learning"
]

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(docs)

# Convert to DataFrame
df_tfidf = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

print(df_tfidf)
# Out:
#         are  artificial      data  includes  intelligence        is  learning  \
# 0  0.534093    0.000000  0.406192  0.000000      0.000000  0.000000  0.315444
# 1  0.000000    0.410747  0.000000  0.000000      0.410747  0.410747  0.242594
# 2  0.000000    0.000000  0.433067  0.569431      0.000000  0.000000  0.336315
#
#     machine        of      part   science  students
# 0  0.000000  0.000000  0.000000  0.406192  0.534093
# 1  0.312384  0.410747  0.410747  0.000000  0.000000
# 2  0.433067  0.000000  0.000000  0.433067  0.000000
